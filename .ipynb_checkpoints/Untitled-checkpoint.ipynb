# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
# Out:
# /home/samyak/Acad/ML/ml_week1/local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = pd.read_csv("Speed Dating Data.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
column_with_nan = df.isnull().sum()

# %%
df.shape[1]
# Out:
# 195

# %%
df.shape
# Out:
# (8378, 195)

# %%
df.size
# Out:
# 1633710

# %%
df[12121:12145]
# Out:
# Empty DataFrame
# Columns: [iid, id, gender, idg, condtn, wave, round, position, positin1, order, partner, pid, match, int_corr, samerace, age_o, race_o, pf_o_att, pf_o_sin, pf_o_int, pf_o_fun, pf_o_amb, pf_o_sha, dec_o, attr_o, sinc_o, intel_o, fun_o, amb_o, shar_o, like_o, prob_o, met_o, age, field, field_cd, undergra, mn_sat, tuition, race, imprace, imprelig, from, zipcode, income, goal, date, go_out, career, career_c, sports, tvsports, exercise, dining, museums, art, hiking, gaming, clubbing, reading, tv, theater, movies, concerts, music, shopping, yoga, exphappy, expnum, attr1_1, sinc1_1, intel1_1, fun1_1, amb1_1, shar1_1, attr4_1, sinc4_1, intel4_1, fun4_1, amb4_1, shar4_1, attr2_1, sinc2_1, intel2_1, fun2_1, amb2_1, shar2_1, attr3_1, sinc3_1, fun3_1, intel3_1, amb3_1, attr5_1, sinc5_1, intel5_1, fun5_1, amb5_1, dec, attr, sinc, ...]
# Index: []

# %%
df[1000:1000]
# Out:
# Empty DataFrame
# Columns: [iid, id, gender, idg, condtn, wave, round, position, positin1, order, partner, pid, match, int_corr, samerace, age_o, race_o, pf_o_att, pf_o_sin, pf_o_int, pf_o_fun, pf_o_amb, pf_o_sha, dec_o, attr_o, sinc_o, intel_o, fun_o, amb_o, shar_o, like_o, prob_o, met_o, age, field, field_cd, undergra, mn_sat, tuition, race, imprace, imprelig, from, zipcode, income, goal, date, go_out, career, career_c, sports, tvsports, exercise, dining, museums, art, hiking, gaming, clubbing, reading, tv, theater, movies, concerts, music, shopping, yoga, exphappy, expnum, attr1_1, sinc1_1, intel1_1, fun1_1, amb1_1, shar1_1, attr4_1, sinc4_1, intel4_1, fun4_1, amb4_1, shar4_1, attr2_1, sinc2_1, intel2_1, fun2_1, amb2_1, shar2_1, attr3_1, sinc3_1, fun3_1, intel3_1, amb3_1, attr5_1, sinc5_1, intel5_1, fun5_1, amb5_1, dec, attr, sinc, ...]
# Index: []

# %%
df[1000:1050]
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 1000   75  10.0       1   20       1     3     10         7       NaN      8
# 1001   75  10.0       1   20       1     3     10         8       NaN      9
# 1002   75  10.0       1   20       1     3     10         6       NaN      7
# 1003   75  10.0       1   20       1     3     10         9       NaN     10
# 1004   75  10.0       1   20       1     3     10         3       NaN      4
# 1005   75  10.0       1   20       1     3     10         2       NaN      3
# 1006   75  10.0       1   20       1     3     10        10       NaN      1
# 1007   75  10.0       1   20       1     3     10         1       NaN      2
# 1008   76   1.0       0    1       2     4     18         5       NaN      9
# 1009   76   1.0       0    1       2     4     18         5       NaN     11
# 1010   76   1.0       0    1       2     4     18         5       NaN     17
# ...

# %%
column_with_nan
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1    1846
# order          0
# partner        0
# pid           10
# match          0
# int_corr     158
# samerace       0
# age_o        104
# race_o        73
# pf_o_att      89
# pf_o_sin      89
# pf_o_int      89
# pf_o_fun      98
# pf_o_amb     107
# pf_o_sha     129
# dec_o          0
# attr_o       212
# sinc_o       287
# intel_o      306
# fun_o        360
# amb_o        722
# shar_o      1076
#             ...
# amb1_3      4404
# shar1_3     4404
# attr7_3     6362
# sinc7_3     6362
# intel7_3    6362
# fun7_3      6362
# amb7_3      6362
# shar7_3     6362
# attr4_3     5419
# sinc4_3     5419
# intel4_3    5419
# fun4_3      5419
# amb4_3      5419
# shar4_3     5419
# attr2_3     5419
# sinc2_3     5419
# intel2_3    5419
# fun2_3      5419
# amb2_3      5419
# shar2_3     6362
# attr3_3     4404
# ...

# %%
df_1 = df.loc[:, column_with_nan < 4000]

# %%
df_1.shape[1]
# Out:
# 130

# %%
df.keys()
# Out:
# Index([u'iid', u'id', u'gender', u'idg', u'condtn', u'wave', u'round',
#        u'position', u'positin1', u'order',
#        ...
#        u'attr3_3', u'sinc3_3', u'intel3_3', u'fun3_3', u'amb3_3', u'attr5_3',
#        u'sinc5_3', u'intel5_3', u'fun5_3', u'amb5_3'],
#       dtype='object', length=195)

# %%
df_1.keys()
# Out:
# Index([u'iid', u'id', u'gender', u'idg', u'condtn', u'wave', u'round',
#        u'position', u'positin1', u'order',
#        ...
#        u'sinc2_2', u'intel2_2', u'fun2_2', u'amb2_2', u'shar2_2', u'attr3_2',
#        u'sinc3_2', u'intel3_2', u'fun3_2', u'amb3_2'],
#       dtype='object', length=130)

# %%
df_1.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
y = df.loc[:, 'match'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
df_1 = df_1.drop(columns='match')

# %%
df_1
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# 5       1   1.0       0    1       1     1     10         7       NaN      6
# 6       1   1.0       0    1       1     1     10         7       NaN      1
# 7       1   1.0       0    1       1     1     10         7       NaN      2
# 8       1   1.0       0    1       1     1     10         7       NaN      8
# 9       1   1.0       0    1       1     1     10         7       NaN      9
# 10      2   2.0       0    3       1     1     10         3       NaN     10
# ...

# %%
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(y)

# %%
df_1
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# 5       1   1.0       0    1       1     1     10         7       NaN      6
# 6       1   1.0       0    1       1     1     10         7       NaN      1
# 7       1   1.0       0    1       1     1     10         7       NaN      2
# 8       1   1.0       0    1       1     1     10         7       NaN      8
# 9       1   1.0       0    1       1     1     10         7       NaN      9
# 10      2   2.0       0    3       1     1     10         3       NaN     10
# ...

# %%
standard_scalar = StandardScaler()

# %%
df_1 = df_1.apply(LabelEncoder().fit_transform)

# %%
cdf_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ed3ab45181b0> in <module>()
# ----> 1 cdf_1
#
# NameError: name 'cdf_1' is not defined

# %%
x = df_1.values

# %%
x_std = standard_scalar.fit_transform(x)
# Out:
# /home/samyak/Acad/ML/ml_week1/local/lib/python2.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x = df_1.ix[:,:].values
# Out:
# /home/samyak/Acad/ML/ml_week1/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
x_std = standard_scalar.fit_transform(x)

# %%
x_std
# Out:
# array([[-1.7808128 , -1.44951594, -1.00119432, ..., -0.3005118 ,
#         -0.30277895, -0.30805827],
#        [-1.7808128 , -1.44951594, -1.00119432, ..., -0.3005118 ,
#         -0.30277895, -0.30805827],
#        [-1.7808128 , -1.44951594, -1.00119432, ..., -0.3005118 ,
#         -0.30277895, -0.30805827],
#        ...,
#        [ 1.69387289,  2.37365976,  0.99880711, ..., -0.30646825,
#         -0.30872928, -0.29021071],
#        [ 1.69387289,  2.37365976,  0.99880711, ..., -0.30646825,
#         -0.30872928, -0.29021071],
#        [ 1.69387289,  2.55571575,  0.99880711, ..., -0.30646825,
#         -0.30872928, -0.29021071]])

# %%
df_1.columns
# Out:
# Index([u'iid', u'id', u'gender', u'idg', u'condtn', u'wave', u'round',
#        u'position', u'positin1', u'order',
#        ...
#        u'sinc2_2', u'intel2_2', u'fun2_2', u'amb2_2', u'shar2_2', u'attr3_2',
#        u'sinc3_2', u'intel3_2', u'fun3_2', u'amb3_2'],
#       dtype='object', length=129)

# %%
counter_with_nan = df_1.isnull().sum()

# %%
counter_with_nan
# Out:
# iid         0
# id          0
# gender      0
# idg         0
# condtn      0
# wave        0
# round       0
# position    0
# positin1    0
# order       0
# partner     0
# pid         0
# int_corr    0
# samerace    0
# age_o       0
# race_o      0
# pf_o_att    0
# pf_o_sin    0
# pf_o_int    0
# pf_o_fun    0
# pf_o_amb    0
# pf_o_sha    0
# dec_o       0
# attr_o      0
# sinc_o      0
# intel_o     0
# fun_o       0
# amb_o       0
# shar_o      0
# like_o      0
#            ..
# like        0
# prob        0
# met         0
# match_es    0
# satis_2     0
# length      0
# numdat_2    0
# attr1_2     0
# sinc1_2     0
# intel1_2    0
# fun1_2      0
# amb1_2      0
# shar1_2     0
# attr4_2     0
# sinc4_2     0
# intel4_2    0
# fun4_2      0
# amb4_2      0
# shar4_2     0
# attr2_2     0
# sinc2_2     0
# intel2_2    0
# fun2_2      0
# amb2_2      0
# shar2_2     0
# attr3_2     0
# sinc3_2     0
# intel3_2    0
# fun3_2      0
# amb3_2      0
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
y.shape
# Out:
# (8378,)

# %%
y.reshape(-1,1)
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
y.shape
# Out:
# (8378,)

# %%
y.T
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
y.T.shape
# Out:
# (8378,)

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
y.T
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
z = y.T

# %%
z.shape
# Out:
# (8378,)

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])
